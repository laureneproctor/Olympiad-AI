# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/laureneproctor/Olympiad-AI.git
# %cd /content/Olympiad-AI
# Out:
# Cloning into 'Olympiad-AI'...
# remote: Enumerating objects: 1476, done.
# remote: Counting objects: 100% (245/245), done.
# remote: Compressing objects: 100% (233/233), done.
# remote: Total 1476 (delta 160), reused 11 (delta 11), pack-reused 1231 (from 3)
# Receiving objects: 100% (1476/1476), 1.59 MiB | 28.51 MiB/s, done.
# Resolving deltas: 100% (880/880), done.
# /content/Olympiad-AI

# %%
# !pip -q install -U \
  transformers \
  datasets \
  peft \
  trl \
  accelerate \
  bitsandbytes \
  pyyaml \
  sentencepiece
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 147.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.0/527.0 kB 60.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 630.8/630.8 kB 82.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 42.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 57.9 MB/s eta 0:00:00

# %%
from aimo3.scripts.grpo import train_grpo
train_grpo("aimo3/configs/grpo_deepseekmath_exp1.yaml")
# Out:
# Experiment: exp1
# Model key: deepseekmath
# Base model: deepseek-ai/deepseek-math-7b-instruct
# Starting checkpoint: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/sft_deepseekmath_exp1
# RL train path: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/rl_train/mined_deepseekmath_exp1_50000
# Output directory: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/grpo_deepseekmath_exp1
# Loading RL dataset from: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/rl_train/mined_deepseekmath_exp1_50000
# RL train rows: 106
# Columns: ['prompt', 'expected_answer', 'problem', 'majority_answer', 'agreement', 'format_validity_rate', 'n_valid_extractions', 'vote_counts', 'mine_reasons']
# Formatting RL dataset
# Formatted columns: ['prompt', 'expected_answer', 'problem', 'majority_answer', 'agreement', 'format_validity_rate', 'n_valid_extractions', 'vote_counts', 'mine_reasons']
# ...

# %%
from aimo3.scripts.grpo import train_grpo
train_grpo("aimo3/configs/grpo_deepseekmath_exp3.yaml")
# Out:
# Experiment: exp3
# Model key: deepseekmath
# Base model: deepseek-ai/deepseek-math-7b-instruct
# Starting checkpoint: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/sft_deepseekmath_exp3
# RL train path: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/rl_train/mined_deepseekmath_exp3_50000
# Output directory: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/grpo_deepseekmath_exp3
# Loading RL dataset from: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/rl_train/mined_deepseekmath_exp3_50000
# RL train rows: 133
# Columns: ['prompt', 'expected_answer', 'problem', 'majority_answer', 'agreement', 'format_validity_rate', 'n_valid_extractions', 'vote_counts', 'mine_reasons']
# Formatting RL dataset
# Formatting RL dataset:   0%|          | 0/133 [00:00<?, ? examples/s]
# ...
