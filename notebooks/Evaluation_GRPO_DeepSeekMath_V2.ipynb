# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/laureneproctor/Olympiad-AI.git
# %cd /content/Olympiad-AI
# Out:
# Cloning into 'Olympiad-AI'...
# remote: Enumerating objects: 1502, done.
# remote: Counting objects: 100% (271/271), done.
# remote: Compressing objects: 100% (259/259), done.
# remote: Total 1502 (delta 181), reused 11 (delta 11), pack-reused 1231 (from 3)
# Receiving objects: 100% (1502/1502), 1.59 MiB | 12.74 MiB/s, done.
# Resolving deltas: 100% (901/901), done.
# /content/Olympiad-AI

# %%
from aimo3.scripts.evaluate import run_evaluation
run_evaluation("/content/Olympiad-AI/aimo3/configs/evaluate_grpo_deepseekmath_exp1.yaml")
# Out:
# Experiment: exp1
# Model key: deepseekmath
# Model name: deepseek-ai/deepseek-math-7b-instruct
# Dataset path: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/processed_splits/omr_aimo3/splits/100000
# Checkpoint: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/grpo_deepseekmath_exp1
# Eval split: test
# Loading evaluation dataset from: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/processed_splits/omr_aimo3/splits/100000
# Loaded eval rows: 10035
# Columns: ['expected_answer', 'problem_type', 'problem_source', 'generation_model', 'pass_rate_72b_tir', 'problem', 'generated_solution', 'inference_mode', 'used_in_kaggle']
# Loading weights:   0%|          | 0/273 [00:00<?, ?it/s]
# Running pass@1 evaluation...
# Pass@1 Evaluation: 100%|██████████| 50/50 [04:27<00:00,  5.35s/example]
# Running maj@N evaluation...
# Maj@8 Evaluation: 100%|██████████| 50/50 [11:17<00:00, 13.56s/example]
# {
#   "metadata": {
# ...

# %%
from aimo3.scripts.evaluate import run_evaluation
run_evaluation("/content/Olympiad-AI/aimo3/configs/evaluate_grpo_deepseekmath_exp3.yaml")
# Out:
# Experiment: exp3
# Model key: deepseekmath
# Model name: deepseek-ai/deepseek-math-7b-instruct
# Dataset path: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/processed_splits/omr_aimo3/splits/100000
# Checkpoint: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/grpo_deepseekmath_exp3
# Eval split: test
# Loading evaluation dataset from: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/processed_splits/omr_aimo3/splits/100000
# Loaded eval rows: 10035
# Columns: ['expected_answer', 'problem_type', 'problem_source', 'generation_model', 'pass_rate_72b_tir', 'problem', 'generated_solution', 'inference_mode', 'used_in_kaggle']
# Loading weights:   0%|          | 0/273 [00:00<?, ?it/s]
# Running pass@1 evaluation...
# Pass@1 Evaluation: 100%|██████████| 50/50 [04:16<00:00,  5.14s/example]
# Running maj@N evaluation...
# Maj@8 Evaluation: 100%|██████████| 50/50 [11:01<00:00, 13.23s/example]
# {
#   "metadata": {
# ...
