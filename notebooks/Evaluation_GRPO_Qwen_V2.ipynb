# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/laureneproctor/Olympiad-AI.git
# %cd /content/Olympiad-AI
# Out:
# Cloning into 'Olympiad-AI'...
# remote: Enumerating objects: 1517, done.
# remote: Counting objects: 100% (286/286), done.
# remote: Compressing objects: 100% (274/274), done.
# remote: Total 1517 (delta 192), reused 11 (delta 11), pack-reused 1231 (from 3)
# Receiving objects: 100% (1517/1517), 1.60 MiB | 13.29 MiB/s, done.
# Resolving deltas: 100% (912/912), done.
# /content/Olympiad-AI

# %%
from aimo3.scripts.evaluate import run_evaluation
run_evaluation("/content/Olympiad-AI/aimo3/configs/evaluate_grpo_qwen_large_v2.yaml")
# Out:
# Experiment: exp1
# Model key: qwen
# Model name: Qwen/Qwen3-8B
# Dataset path: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/processed_splits/omr_aimo3/splits/100000
# Checkpoint: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/grpo_qwen_exp1
# Eval split: test
# Loading evaluation dataset from: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/processed_splits/omr_aimo3/splits/100000
# Loaded eval rows: 10035
# Columns: ['expected_answer', 'problem_type', 'problem_source', 'generation_model', 'pass_rate_72b_tir', 'problem', 'generated_solution', 'inference_mode', 'used_in_kaggle']
# Loading weights:   0%|          | 0/399 [00:00<?, ?it/s]
# Running pass@1 evaluation...
# Pass@1 Evaluation: 100%|██████████| 50/50 [09:55<00:00, 11.91s/example]
# Running maj@N evaluation...
# Maj@8 Evaluation: 100%|██████████| 50/50 [15:58<00:00, 19.16s/example]
# {
#   "metadata": {
#     "experiment_name": "exp1",
#     "model_key": "qwen",
#     "model_name": "Qwen/Qwen3-8B",
#     "checkpoint": "/content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/grpo_qwen_exp1",
#     "dataset_path": "/content/drive/MyDrive/Math Olympiad Competition/Experimentation/processed_splits/omr_aimo3/splits/100000",
#     "split": "test",
#     "n_dataset_rows": 10035
#   },
#   "pass1": {
#     "pass@1": 0.3,
#     "format_valid_rate": 1.0,
#     "n": 50
#   },
#   "majn": {
#     "maj@8": 0.32,
#     "per_sample_format_valid_rate": 0.95,
#     "per_problem_any_valid_rate": 1.0,
#     "avg_agreement_rate": 0.4904047619047619,
#     "n": 50
#   }
# }
# Saved evaluation report to: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/runs/large_evaluation_grpo_qwen_exp1_v2/evaluation_report_grpo_qwen_exp1.json
# {'metadata': {'experiment_name': 'exp1',
#   'model_key': 'qwen',
#   'model_name': 'Qwen/Qwen3-8B',
#   'checkpoint': '/content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/grpo_qwen_exp1',
#   'dataset_path': '/content/drive/MyDrive/Math Olympiad Competition/Experimentation/processed_splits/omr_aimo3/splits/100000',
#   'split': 'test',
#   'n_dataset_rows': 10035},
#  'pass1': {'pass@1': 0.3, 'format_valid_rate': 1.0, 'n': 50},
#  'majn': {'maj@8': 0.32,
#   'per_sample_format_valid_rate': 0.95,
#   'per_problem_any_valid_rate': 1.0,
#   'avg_agreement_rate': 0.4904047619047619,
#   'n': 50}}

# %%
from aimo3.scripts.evaluate import run_evaluation
run_evaluation("/content/Olympiad-AI/aimo3/configs/evaluate_grpo_qwen_exp3.yaml")
# Out:
# Experiment: exp3
# Model key: qwen
# Model name: Qwen/Qwen3-8B
# Dataset path: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/processed_splits/omr_aimo3/splits/100000
# Checkpoint: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/grpo_qwen_exp3
# Eval split: test
# Loading evaluation dataset from: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/processed_splits/omr_aimo3/splits/100000
# Loaded eval rows: 10035
# Columns: ['expected_answer', 'problem_type', 'problem_source', 'generation_model', 'pass_rate_72b_tir', 'problem', 'generated_solution', 'inference_mode', 'used_in_kaggle']
# Loading weights:   0%|          | 0/399 [00:00<?, ?it/s]
# Running pass@1 evaluation...
# Pass@1 Evaluation: 100%|██████████| 50/50 [10:02<00:00, 12.05s/example]
# Running maj@N evaluation...
# Maj@8 Evaluation: 100%|██████████| 50/50 [16:18<00:00, 19.56s/example]
# {
#   "metadata": {
#     "experiment_name": "exp3",
#     "model_key": "qwen",
#     "model_name": "Qwen/Qwen3-8B",
#     "checkpoint": "/content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/grpo_qwen_exp3",
#     "dataset_path": "/content/drive/MyDrive/Math Olympiad Competition/Experimentation/processed_splits/omr_aimo3/splits/100000",
#     "split": "test",
#     "n_dataset_rows": 10035
#   },
#   "pass1": {
#     "pass@1": 0.18,
#     "format_valid_rate": 1.0,
#     "n": 50
#   },
#   "majn": {
#     "maj@8": 0.26,
#     "per_sample_format_valid_rate": 0.94,
#     "per_problem_any_valid_rate": 1.0,
#     "avg_agreement_rate": 0.47,
#     "n": 50
#   }
# }
# Saved evaluation report to: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/runs/evaluation_grpo_qwen_exp3/evaluation_report_grpo_qwen_exp3.json
# {'metadata': {'experiment_name': 'exp3',
#   'model_key': 'qwen',
#   'model_name': 'Qwen/Qwen3-8B',
#   'checkpoint': '/content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/grpo_qwen_exp3',
#   'dataset_path': '/content/drive/MyDrive/Math Olympiad Competition/Experimentation/processed_splits/omr_aimo3/splits/100000',
#   'split': 'test',
#   'n_dataset_rows': 10035},
#  'pass1': {'pass@1': 0.18, 'format_valid_rate': 1.0, 'n': 50},
#  'majn': {'maj@8': 0.26,
#   'per_sample_format_valid_rate': 0.94,
#   'per_problem_any_valid_rate': 1.0,
#   'avg_agreement_rate': 0.47,
#   'n': 50}}
