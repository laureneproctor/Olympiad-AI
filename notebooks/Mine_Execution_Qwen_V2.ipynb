# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
if not os.path.exists('/content/Olympiad-AI'):
    # !git clone https://github.com/laureneproctor/Olympiad-AI.git
# %cd /content/Olympiad-AI
# !pip -q install -U pip
# !pip -q install torch transformers datasets peft pyyaml tqdm accelerate bitsandbytes
# Out:
# Cloning into 'Olympiad-AI'...
# remote: Enumerating objects: 1507, done.
# remote: Counting objects: 100% (276/276), done.
# remote: Compressing objects: 100% (264/264), done.
# remote: Total 1507 (delta 184), reused 11 (delta 11), pack-reused 1231 (from 3)
# Receiving objects: 100% (1507/1507), 1.59 MiB | 5.23 MiB/s, done.
# Resolving deltas: 100% (904/904), done.
# /content/Olympiad-AI
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 38.0 MB/s eta 0:00:00

# %%
from aimo3.scripts.mine import mine_failures; mine_failures("aimo3/configs/large_mine_qwen_v2.yaml")
# Out:
# Loading mining dataset from: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/processed_splits/omr_aimo3/splits/exp1/50000
# Mining rows: 4858
# Columns: ['expected_answer', 'problem_type', 'problem_source', 'generation_model', 'pass_rate_72b_tir', 'problem', 'generated_solution', 'inference_mode', 'used_in_kaggle', 'reasoning_quality_rating']
# Applied max_items cap: 450
# Loading tokenizer from: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/sft_qwen_exp1
# Trying to load as PEFT adapter checkpoint
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/728 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/399 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/peft/utils/save_and_load.py:587: UserWarning: Some weights of PeftModelForCausalLM were not initialized from the model checkpoint and are being ignored because you passed `ignore_mismatched_sizes=True`: - base_model.model.lm_head.weight: found shape torch.Size([151669, 4096]) in the checkpoint and torch.Size([151936, 4096]) in the model instantiated
# - base_model.model.model.embed_tokens.weight: found shape torch.Size([151669, 4096]) in the checkpoint and torch.Size([151936, 4096]) in the model instantiated.
#   warnings.warn(msg)
# Resizing token embeddings from 151936 to 151669
# Mining examples: 100%|██████████| 450/450 [12:04:22<00:00, 96.58s/example]
# Saving the dataset (0/1 shards):   0%|          | 0/406 [00:00<?, ? examples/s]
# Saved mined dataset to: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/rl_train/mined_qwen_large
# Mined examples: 406 / 450
# Saved mining report to: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/runs/mining_report_qwen_large.json

# %%
from aimo3.scripts.mine import mine_failures; mine_failures("aimo3/configs/mine_qwen_exp3.yaml")
# Out:
# Loading mining dataset from: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/processed_splits/omr_aimo3/splits/exp3/50000
# Mining rows: 5061
# Columns: ['expected_answer', 'problem_type', 'problem_source', 'generation_model', 'pass_rate_72b_tir', 'problem', 'generated_solution', 'inference_mode', 'used_in_kaggle', 'reasoning_quality_rating']
# Applied max_items cap: 150
# Loading tokenizer from: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/sft_qwen_exp3
# Trying to load as PEFT adapter checkpoint
# Loading weights:   0%|          | 0/399 [00:00<?, ?it/s]
# Resizing token embeddings from 151936 to 151669
# Mining examples: 100%|██████████| 150/150 [4:03:05<00:00, 97.24s/example]
# Saving the dataset (0/1 shards):   0%|          | 0/145 [00:00<?, ? examples/s]
# Saved mined dataset to: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/rl_train/mined_qwen_exp3_50000
# Mined examples: 145 / 150
# Saved mining report to: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/runs/mining_report_qwen_exp3_50000.json
