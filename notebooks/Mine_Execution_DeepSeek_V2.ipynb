# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Colab setup: clone repo if needed, then install deps
import os
if not os.path.exists('/content/Olympiad-AI'):
    # !git clone https://github.com/laureneproctor/Olympiad-AI.git
# %cd /content/Olympiad-AI
# !pip -q install -U pip
# !pip -q install torch transformers datasets peft pyyaml tqdm accelerate bitsandbytes
# Out:
# Cloning into 'Olympiad-AI'...
# remote: Enumerating objects: 1422, done.
# remote: Counting objects: 100% (191/191), done.
# remote: Compressing objects: 100% (179/179), done.
# remote: Total 1422 (delta 128), reused 11 (delta 11), pack-reused 1231 (from 3)
# Receiving objects: 100% (1422/1422), 1.53 MiB | 8.22 MiB/s, done.
# Resolving deltas: 100% (848/848), done.
# /content/Olympiad-AI
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 51.1 MB/s eta 0:00:00

# %%
from aimo3.scripts.mine import mine_failures; mine_failures("aimo3/configs/mine_deepseekmath_exp1.yaml")
# Out:
# Loading mining dataset from: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/processed_splits/omr_aimo3/splits/exp1/50000
# Mining rows: 4858
# Columns: ['expected_answer', 'problem_type', 'problem_source', 'generation_model', 'pass_rate_72b_tir', 'problem', 'generated_solution', 'inference_mode', 'used_in_kaggle', 'reasoning_quality_rating']
# Applied max_items cap: 150
# Loading tokenizer from: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/sft_deepseekmath_exp1
# Trying to load as PEFT adapter checkpoint
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# ...

# %%
from aimo3.scripts.mine import mine_failures; mine_failures("aimo3/configs/mine_deepseekmath_exp3.yaml")
# Out:
# Loading mining dataset from: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/processed_splits/omr_aimo3/splits/exp3/50000
# Mining rows: 5061
# Columns: ['expected_answer', 'problem_type', 'problem_source', 'generation_model', 'pass_rate_72b_tir', 'problem', 'generated_solution', 'inference_mode', 'used_in_kaggle', 'reasoning_quality_rating']
# Applied max_items cap: 150
# Loading tokenizer from: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/sft_deepseekmath_exp3
# Trying to load as PEFT adapter checkpoint
# Loading weights:   0%|          | 0/273 [00:00<?, ?it/s]
# Resizing token embeddings from 102400 to 100002
# ...
# Saving the dataset (0/1 shards):   0%|          | 0/133 [00:00<?, ? examples/s]
# Saved mined dataset to: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/rl_train/mined_deepseekmath_exp3_50000
# Mined examples: 133 / 150
# ...
