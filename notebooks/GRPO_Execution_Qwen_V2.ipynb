# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/laureneproctor/Olympiad-AI.git
# %cd /content/Olympiad-AI
# Out:
# Cloning into 'Olympiad-AI'...
# remote: Enumerating objects: 1512, done.
# remote: Counting objects: 100% (281/281), done.
# remote: Compressing objects: 100% (269/269), done.
# remote: Total 1512 (delta 188), reused 11 (delta 11), pack-reused 1231 (from 3)
# Receiving objects: 100% (1512/1512), 1.60 MiB | 4.65 MiB/s, done.
# Resolving deltas: 100% (908/908), done.
# /content/Olympiad-AI

# %%
# !pip -q install -U \
  transformers \
  datasets \
  peft \
  trl \
  accelerate \
  bitsandbytes \
  pyyaml \
  sentencepiece
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 153.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.0/527.0 kB 56.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 678.0/678.0 kB 86.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 48.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 58.6 MB/s eta 0:00:00

# %%
from aimo3.scripts.grpo import train_grpo
train_grpo("aimo3/configs/large_grpo_gwen_v2.yaml")
# Out:
# Experiment: exp1
# Model key: qwen
# Base model: Qwen/Qwen3-8B
# Starting checkpoint: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/sft_qwen_exp1
# RL train path: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/rl_train/mined_qwen_large
# Output directory: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/grpo_qwen_exp1
# Loading RL dataset from: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/rl_train/mined_qwen_large
# RL train rows: 406
# Columns: ['prompt', 'expected_answer', 'problem', 'majority_answer', 'agreement', 'format_validity_rate', 'n_valid_extractions', 'vote_counts', 'mine_reasons']
# Formatting RL dataset
# Formatted columns: ['prompt', 'expected_answer', 'problem', 'majority_answer', 'agreement', 'format_validity_rate', 'n_valid_extractions', 'vote_counts', 'mine_reasons']
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/728 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/399 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/505 [00:00<?, ?it/s]
# Qwen3ForCausalLM LOAD REPORT from: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/sft_qwen_exp1
# Key                             | Status     |
# --------------------------------+------------+---------------------------------------------------------------------------------------------------
# base_model.model.lm_head.weight | UNEXPECTED |
# model.embed_tokens.weight       | MISMATCH   | Reinit due to size mismatch - ckpt: torch.Size([151669, 4096]) vs model:torch.Size([151936, 4096])
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISMATCH:	ckpt weights were loaded, but they did not match the original empty weight shapes.
# Warning: checkpoint load had shape mismatches. Retrying with ignore_mismatched_sizes=True.
# Loading weights:   0%|          | 0/399 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/505 [00:00<?, ?it/s]
# Qwen3ForCausalLM LOAD REPORT from: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/sft_qwen_exp1
# Key                             | Status     |
# --------------------------------+------------+---------------------------------------------------------------------------------------------------
# base_model.model.lm_head.weight | UNEXPECTED |
# model.embed_tokens.weight       | MISMATCH   | Reinit due to size mismatch - ckpt: torch.Size([151669, 4096]) vs model:torch.Size([151936, 4096])
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISMATCH:	ckpt weights were loaded, but they did not match the original empty weight shapes.
# Note: dropped unsupported GRPOConfig params for this TRL version: {'max_prompt_length'}
# /usr/local/lib/python3.12/dist-packages/peft/mapping_func.py:72: UserWarning: You are trying to modify a model with PEFT for a second time. If you want to reload the model with a different config, make sure to call `.unload()` before.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/peft/tuners/tuners_utils.py:285: UserWarning: Already found a `peft_config` attribute in the model. This will lead to having multiple adapters in the model. Make sure to know what you are doing!
#   warnings.warn(
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
# Starting GRPO training
#     <div>
#
#       <progress value='203' max='203' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [203/203 32:13, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>20</td>
#       <td>0.000016</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.000016</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.000021</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.000017</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.000061</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.000017</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.000019</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.000020</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.000019</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.000019</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving GRPO model + tokenizer
# Done. Saved to: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/grpo_qwen_exp1

# %%
from aimo3.scripts.grpo import train_grpo
train_grpo("aimo3/configs/grpo_qwen_exp3.yaml")
# Out:
# Experiment: exp3
# Model key: qwen
# Base model: Qwen/Qwen3-8B
# Starting checkpoint: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/sft_qwen_exp3
# RL train path: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/rl_train/mined_qwen_exp3_50000
# Output directory: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/grpo_qwen_exp3
# Loading RL dataset from: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/rl_train/mined_qwen_exp3_50000
# RL train rows: 145
# Columns: ['prompt', 'expected_answer', 'problem', 'majority_answer', 'agreement', 'format_validity_rate', 'n_valid_extractions', 'vote_counts', 'mine_reasons']
# Formatting RL dataset
# Formatting RL dataset:   0%|          | 0/145 [00:00<?, ? examples/s]
# Formatted columns: ['prompt', 'expected_answer', 'problem', 'majority_answer', 'agreement', 'format_validity_rate', 'n_valid_extractions', 'vote_counts', 'mine_reasons']
# Loading weights:   0%|          | 0/399 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/505 [00:00<?, ?it/s]
# Qwen3ForCausalLM LOAD REPORT from: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/sft_qwen_exp3
# Key                             | Status     |
# --------------------------------+------------+---------------------------------------------------------------------------------------------------
# base_model.model.lm_head.weight | UNEXPECTED |
# model.embed_tokens.weight       | MISMATCH   | Reinit due to size mismatch - ckpt: torch.Size([151669, 4096]) vs model:torch.Size([151936, 4096])
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISMATCH:	ckpt weights were loaded, but they did not match the original empty weight shapes.
# Warning: checkpoint load had shape mismatches. Retrying with ignore_mismatched_sizes=True.
# Loading weights:   0%|          | 0/399 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/505 [00:00<?, ?it/s]
# Qwen3ForCausalLM LOAD REPORT from: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/sft_qwen_exp3
# Key                             | Status     |
# --------------------------------+------------+---------------------------------------------------------------------------------------------------
# base_model.model.lm_head.weight | UNEXPECTED |
# model.embed_tokens.weight       | MISMATCH   | Reinit due to size mismatch - ckpt: torch.Size([151669, 4096]) vs model:torch.Size([151936, 4096])
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISMATCH:	ckpt weights were loaded, but they did not match the original empty weight shapes.
# /usr/local/lib/python3.12/dist-packages/peft/mapping_func.py:72: UserWarning: You are trying to modify a model with PEFT for a second time. If you want to reload the model with a different config, make sure to call `.unload()` before.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/peft/tuners/tuners_utils.py:285: UserWarning: Already found a `peft_config` attribute in the model. This will lead to having multiple adapters in the model. Make sure to know what you are doing!
#   warnings.warn(
# Note: dropped unsupported GRPOConfig params for this TRL version: {'max_prompt_length'}
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
# Starting GRPO training
#     <div>
#
#       <progress value='72' max='72' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [72/72 11:16, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>20</td>
#       <td>0.000015</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.000017</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.000018</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving GRPO model + tokenizer
# Done. Saved to: /content/drive/MyDrive/Math Olympiad Competition/Experimentation/models/grpo_qwen_exp3
